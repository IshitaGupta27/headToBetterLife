# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
Book_Info=[]
Url_Info=[]
Abstract_Info=[]
output_rows =pd.DataFrame(columns = ['BOOK_NAME', 'ABSTRACT','URL'])
for i in range(0,140,20):
    url="https://www.smashwords.com/books/category/511/newest/0/free/any/"+str(i)
    page=requests.get(url)
    soup=BeautifulSoup(page.content,"html.parser")
    for link in soup.find_all(class_='library-title'):
        Book_Info.append(link.get_text())
        Url_Info.append(link.get('href'))
    for linkp in soup.find_all(class_='card bg-light border-light p-2'):
        Abstract_Info.append(linkp.get_text())

# %%
ABSTRACT = [item.strip() for item in Abstract_Info if str(item)]
output_rows['BOOK_NAME'] = Book_Info
output_rows['ABSTRACT']=ABSTRACT
output_rows['URL']=Url_Info

# %%
output_rows
# Out:
#                                              BOOK_NAME  \
# 0    Love for a Deaf Rebel: Schizophrenia on Bowen ...
# 1    A Walk In My Shoes: An Autobiographical Self-H...
# 2                                       AA Abbreviated
# 3    Buah Dan Tanaman Herbal Yang Berkhasiat Untuk ...
# 4                         Refreshing Mindset Made Easy
# ..                                                 ...
# 121                          Narcissism Book of Quotes
# 122        Factors that Trigger Depression and Anxiety
# 123        Pandemic Influenza:  Mental Health Response
# 124           Disaster Strikes:  Just-In-Time Training
# 125                                     When I Grow Up
#
#                                               ABSTRACT  \
# 0    Love for a Deaf Rebel introduces readers to a ...
# 1    What started out as an autobiography to pass o...
# 2    Getting sober in AA or other twelve step progr...
# 3    Mengenal Berbagai Buah Dan Tanaman Herbal Yang...
# 4    Do you feel worried, frightened, nervous, frus...
# ..                                                 ...
# 121  The Narcissistic Personality Disorder (NPD) an...
# 122  This eBook is an excellent Self-Help Guide for...
# 123  A primer on pandemic influenza, for anyone who...
# 124  First responders, mental health professionals,...
# 125  We all experience growing pains.  It can be be...
#
#                                                URL
# 0    https://www.smashwords.com/books/view/1076109
# 1    https://www.smashwords.com/books/view/1067248
# 2    https://www.smashwords.com/books/view/1060935
# 3    https://www.smashwords.com/books/view/1060929
# 4    https://www.smashwords.com/books/view/1060894
# ..                                             ...
# 121     https://www.smashwords.com/books/view/8016
# 122     https://www.smashwords.com/books/view/6125
# 123     https://www.smashwords.com/books/view/2768
# 124     https://www.smashwords.com/books/view/2767
# 125      https://www.smashwords.com/books/view/655
#
# [126 rows x 3 columns]

# %%
output_rows.to_csv('BOOKS.csv')

# %%
# !pip install selenium
import csv
#Importing packages
from selenium import webdriver
import pandas as pd
driver = webdriver.Chrome('C:\Program Files\chromedriver_win32\chromedriver.exe')
driver.get('https://adaa.org/helpful-inspiring-songs')

first_part="//*[@id='block-bootstrap-sass-content']/div/div/div/ul[1]/li["
second_part="]/a"

file=open("product.csv","wt",newline='')
writer=csv.writer(file)

song_name=[]
Url=[]
output =pd.DataFrame(columns = ['SONG_NAME', 'URL'])
for n in range(1,28):
        final_path=first_part+str(n)+second_part
        table_data= driver.find_element_by_xpath(final_path)
        song_name.append(table_data.text)
        Url.append(table_data.get_attribute('href'))
        
        
output['SONG_NAME'] = song_name
output['URL']=Url
output.to_csv('SONGS.csv')
# Out:
# Requirement already satisfied: selenium in c:\programdata\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.25.9)
